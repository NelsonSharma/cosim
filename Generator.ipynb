# %%
from cosim.gene import FlowGen

G = FlowGen(
    "ue", 
    datadir="__infra__/ue/data", 
    flowdir="__flowdb__",
    seed=12,
)
G

# %%
choosen, choosen_inputs, status_code, text, url = G.generate_flow(
    offloaderURL="http://127.0.0.1:9696"
)
status_code

# %%
choosen

# %%
choosen_inputs

# %%
text

# %%
url

# %%
raise StopIteration

# %%
# wait for results

# %%
#import requests
from cosim import Manager
data_url = text['data_url']
out, code = Manager.GetResult(data_url)
print(f'{data_url} {code = }\n\n')
print(f'{choosen_inputs = }\n')
print(f'{out = }')
