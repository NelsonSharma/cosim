# %% [markdown]
# # Testing

# %%
from cosim.fs import Requestor as R
ueep = "127.0.0.1:8888"
omep = "127.0.0.1:8000"
cnep0 = "127.0.0.1:8800"
cnep1 = "127.0.0.1:8801"
cnep2 = "127.0.0.1:8802"
R.Ping(ueep), R.Ping(omep), R.Ping(cnep0), R.Ping(cnep1), R.Ping(cnep2)
# Out:
# (True, True, True, True, True)

# %%
success, nodes = R.NodeList(omep)
print(success)
nodes
# Out:
# True
# {'CN0': '172.18.0.1:8800', 'CN1': '172.18.0.1:8801', 'CN2': '172.18.0.1:8802'}

# %%
success, states = R.StateList(omep)
print(success)
states
# Out:
# True
# {'CN0': ['2026-07-06-13-57-42-253548',
#   '2026-07-06-13-57-46-260080',
#   '2026-07-06-13-57-50-263722'],
#  'CN1': ['2026-07-06-13-57-43-136078',
#   '2026-07-06-13-57-47-147695',
#   '2026-07-06-13-57-51-151812'],
#  'CN2': ['2026-07-06-13-57-44-224776', '2026-07-06-13-57-48-231192']}

# %%
success, tids = R.QueueList(omep)
print(success)
tids
# Out:
# True
# []

# %%
R.Send(ueep,  node='CN0')
# Out:
# (True,
#  {'exe': 'other.py',
#   'name': 'tester',
#   'requested_node': 'CN0',
#   'size': 1400,
#   'source': '172.18.0.1:8888',
#   'tid': 'UE20260706135812303559',
#   'ts-sent': '2026:07:06:13:58:12:304878',
#   'uid': 'UE'})

# %%
R.Send(ueep, name='tester',  node='CN1')
# Out:
# (True,
#  {'exe': 'other.py',
#   'name': 'tester',
#   'requested_node': 'CN1',
#   'size': 1400,
#   'source': '172.18.0.1:8888',
#   'tid': 'UE20260706135817988549',
#   'ts-sent': '2026:07:06:13:58:17:990484',
#   'uid': 'UE'})

# %%
R.Send(ueep, name='tester', exe='other.py', node='CN2')
# Out:
# (True,
#  {'exe': 'other.py',
#   'name': 'tester',
#   'requested_node': 'CN2',
#   'size': 1400,
#   'source': '172.18.0.1:8888',
#   'tid': 'UE20260706135821383155',
#   'ts-sent': '2026:07:06:13:58:21:384846',
#   'uid': 'UE'})

# %%
# ue sends a task-------------------
import time
for _ in range(12):
    #time.sleep(1)
    success, task = R.Send(ueep)
    print(success, task['tid'])
# Out:
# True UE20260706135831716202
# True UE20260706135831736465
# True UE20260706135831750339
# True UE20260706135831764496
# True UE20260706135831776724
# True UE20260706135831787276
# True UE20260706135831795349
# True UE20260706135831807006
# True UE20260706135831815951
# True UE20260706135831826228
# True UE20260706135831832206
# True UE20260706135831837869

# %%
raise StopAsyncIteration

# %%
R.Stop(cnep0), R.Stop(cnep1), R.Stop(cnep2)
# Out:
# (True, True, True)

# %%
R.Stop(ueep)
# Out:
# True

# %%
R.Stop(omep)
# Out:
# True
